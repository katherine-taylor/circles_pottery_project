# %% [markdown]
# # Data Prep
# To do: take actual image data and turn it into the dataframe needed.
#
# 1) Import images
# 2) Turn images into data
# 3) Get four points on the edge of the plate somehow (with measurements)

# %%
# libraries

# %% [markdown]
# ##
